# %%
import pandas as pd
from app.scripts.data_fetchers.broker_data import BrokerData

# %%
a = BrokerData.get_master_data()
a_df = pd.DataFrame(a['data'])
a_df
# Out:
#       weekly segment      name exchange        expiry instrument_type  \
# 0       True  NCD_FO    USDINR      NSE  1.748630e+12              PE
# 1       True  NCD_FO    EURINR      NSE  1.748630e+12              CE
# 2       True  NCD_FO    EURINR      NSE  1.748630e+12              PE
# 3      False  NCD_FO    JPYINR      NSE  1.774636e+12              CE
# 4       True  NCD_FO    USDINR      NSE  1.748630e+12              CE
# ...      ...     ...       ...      ...           ...             ...
# 96632   True  BCD_FO    GBPINR      BSE  1.745606e+12              CE
# 96633   True  NCD_FO    USDINR      NSE  1.743791e+12              CE
# 96634  False  BSE_FO    BANKEX      BSE  1.750790e+12              PE
# 96635  False  BSE_FO  SENSEX50      BSE  1.750790e+12              CE
# 96636   True  BCD_FO    EURINR      BSE  1.745606e+12              PE
#
#       asset_symbol underlying_symbol  instrument_key  lot_size  ...  \
# ...

# %%
a_df.to_csv('Upstox_Master_File_1.csv')

# %%
# !aws s3 cp "/home/admin/Plus91Backoffice/plus91_management/Upstox_Master_File_1.csv" "s3://plus91generalpurpose/"
# Out:
# upload: ./Upstox_Master_File_1.csv to s3://plus91generalpurpose/Upstox_Master_File_1.csv
